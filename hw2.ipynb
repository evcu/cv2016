-- %%
require 'image';

-- %%
itorch.image({image.lena(),image.lena(),image.lena()})
-- Out:
-- Console does not support images

-- %%
help(torch.permute)
-- Out:
-- +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
-- [Tensor] permute(dim1, dim2, ..., dimn)
--
--
-- Generalizes the function transpose() and can be used
-- as a convenience method replacing a sequence of transpose() calls.
-- Returns a tensor where the dimensions were permuted according to the permutation
-- given by (dim1, dim2, ... , dimn). The permutation must be specified fully,
-- i.e.
-- there must be as many parameters as the tensor has dimensions.
--  x = torch.Tensor(3,4,2,5)
-- > x:size()
--  3
--  4
--  2
--  5
-- [torch.LongStorage of size 4]
-- y = x:permute(2,3,1,4) -- equivalent to y = x:transpose(1,3):transpose(1,2)
-- > y:size()
--  4
--  2
--  3
--  5
-- [torch.LongStorage of size 4]
-- +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

-- %%
local base_data_path = '/Users/evcu/Google Drive/Courses/CompVision/assign2/data/'
local trainset = torch.load(base_data_path .. 'train_28x28.t7', 'ascii')
print(trainset.data)
i=24232
print(trainset.labels[24232])
itorch.image(trainset.data[24232])
